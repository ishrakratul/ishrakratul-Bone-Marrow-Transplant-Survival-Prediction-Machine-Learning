# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data1=pd.read_csv ("manipulated data.csv")
data=data1.drop('sl',axis=1)

# %%
data.shape
# Out:
# (187, 59)

# %%
x=data.drop('survival_status',axis=1)
y=data['survival_status']

# %%
x_train_11,x_test_11,y_train_11,y_test_11=train_test_split(x,y,test_size=0.2, random_state=None, shuffle=True, stratify=y)

# %%
x_train_11.shape
# Out:
# (149, 58)

# %%
x_test_11.shape
# Out:
# (38, 58)

# %%
x_train_11.to_csv('x_train_all.csv')

# %%
y_train_11.to_csv('y_train_all.csv')

# %%
x_test_11.to_csv('x_test_all.csv')

# %%
y_test_11.to_csv('y_test_all.csv')
